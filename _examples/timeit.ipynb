# %%
import chunkypandas as cpd
import numpy as np
import pandas as pd

# %%
n = 0
n_rows = 1000
n_cols = 10
df = pd.DataFrame(np.random.rand(n_rows, n_cols))
df.to_csv('test.csv')

# %%
# %%timeit
x = df.count()
# Out:
# 89 ms ± 6.52 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
cdf = cpd.ChunkyDataFrame('test.csv')
del df

# %%
# %%timeit
y = cdf.count()

# %%
cdf.count()
